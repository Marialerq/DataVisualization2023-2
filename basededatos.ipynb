# %% [markdown]
# <a href="https://colab.research.google.com/github/Marialerq/DataVisualization2023-2/blob/main/basededatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align = "center">
# <strong> Universidad de La Salle </strong>
# </h1>
#
# <h1 align = "center">
# <strong> Finance and International Commerce Program </strong>
# </h1>
#
# <h1 align = "center">
# <strong> Data Visualization </strong>
# </h1>

# %% [markdown]
# ##**1.Description of the variables, frequency, measurement, where it is taken from variables**
#
# - *Current health spending per capita*
#         Description: Current expenditure on health per capita includes health goods and services consumed during each year.
#         Frequency: 2000 - 2021
#         Measurement: USD
#         Database: World Bank source World Health Organization
# - *Crude mortality rate*
#         Description: The crude mortality rate indicates the number of deaths per 1,000 inhabitan
#         Frequency: 2000 - 2021
#         Measurement: per 1,0000
#         Database: World Bank
# - *Population growth*
#         Description:  Annual population growth rate. Population is based on the de facto definition of population, which counts all residents regardless of status
#         Frequency: 2000 - 2021
#         Measurement: Percentage
#         Database: World Bank

# %% [markdown]
# ## **2. What is the objective, what is the message, hypothesis** ##
#
# - **Hypothesis:** If national spending on health per capita increases, the mortality rate decreases and therefore population growth increases.
# - **Objective:** Analyze the behavior in terms of health in the 195 countries of the world.

# %% [markdown]
# ## **3. Two examples, two images that look like what I want to do** ##

# %% [markdown]
# ## 1. Example![5XNSDIO2CZHEFD2L5XBXN6O33M.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Example
# ![descarga.jpg](data:image/jpeg;base64,...)
