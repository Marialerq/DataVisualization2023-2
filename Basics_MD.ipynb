# %% [markdown]
# <a href="https://colab.research.google.com/github/Marialerq/DataVisualization2023-2/blob/main/Basics_MD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Title

# %% [markdown]
# ## Subtitle

# %% [markdown]
# #TITLE 2

# %% [markdown]
# # **Text formating**

# %% [markdown]
# ## Bold the words

# %% [markdown]
# Use "**" at the begining and the end
#
# **María Alejandra Rodriguez**

# %% [markdown]
# ## Italics
#
# Use "*" at the begining and at the end
#
# *Maria Alejandra Rodriguez*

# %% [markdown]
# ## Underline
#
# You cannot
#
# <ins>prueba</ins>

# %% [markdown]
# ## Bold and italics
#
# Use "***" at the begining and the end
#
# ***Maria Alejandra Rodriguez***

# %% [markdown]
# # **lists**
#
# ## Unorderd list
#
# Just bullets.
#
# For example:
#
# **My hobbies:**
# * Do excercise
# * Play tennis
# * Listen music

# %% [markdown]
# ## Ordered list
#
# Just use numbers ...
#
# For example
#
# **My top 5 singers**
# 1. Maluma
# 2. Fied
# 3. Karol G
# 4. Shakira
# 5. Vives

# %% [markdown]
# ## Nested list
#
# For example:
#
# **My daily routine**
# 1. Morning
#
#     1.1 Wape up
#
#     1.2 Eat breakfast
#
#     1.3 Take a shower
#
#     1.4 Go to work
#
# 2. Afternoon
#
#     2.1 Eat the lunch
#
#     2.2 Study
#
# 3. Night
#
#     3.1 Eat the dinner
#
#     3.2 Go to the bed

# %% [markdown]
# #**Inserts**

# %% [markdown]
# ## Links
#
# [La Salle](https://www.lasalle.edu.co/)

# %% [markdown]
# ## Images
#
# ![texto del enlace](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png)

# %% [markdown]
# ![chris-ried-ieic5Tq8YMk-unsplash.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Video**

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/MkO9g3ywnG4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/MkO9g3ywnG4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# # **A simple table**
#
# | First name | Last name |
# | -----------|-----------|
# | Maria      | Rodriguez |
# | Alejandra  | Quintero  |

# %% [markdown]
# # **Equation**
#
# For example *The pytagors theorem*
#
# $a^2 + b^2 = c^2$
#
# $\begin{equation}
# a^2 + b^2 = c^2
# \end{equation}$
